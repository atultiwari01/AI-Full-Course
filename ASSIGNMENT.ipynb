# %% [markdown]
# <a href="https://colab.research.google.com/github/atultiwari01/AI-Full-Course/blob/main/ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using the given **medical dataset**, perform disease **classification** using a Machine Learning algorithm such as **Logistic Regression**.
#
# Tasks:
#
# 1.Import the dataset into Google Colab.
# 2.Perform data preprocessing (handle missing values, encode categorical features if needed, and normalize/standardize data).
# 3.Split the dataset into training (80%) and testing (20%).
# 4.Train a classification model.
# 5.Evaluate the model using:
# Accuracy
# Precision
# Recall
# F1-score
# Confusion Matrix

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, mean_absolute_error, mean_squared_error, r2_score

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df = pd.read_csv(url, names=cols)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.7532467532467533

# %%
print(f"Precision: {precision_score(y_test, y_pred)}")
# Out:
# Precision: 0.6491228070175439

# %%
print(f"Recall: {recall_score(y_test, y_pred)}")
# Out:
# Recall: 0.6727272727272727

# %%
print(f"F1: {f1_score(y_test, y_pred)}")
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.show()
# Out:
# F1: 0.6607142857142857

# %% [markdown]
# Using the same medical dataset, perform **Data Visualization**
#
# Using Matplotlib:
#
# Create a Line Chart.
# Create a Bar Chart.
# Create a Pie Chart.

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
df["Glucose"].head(10).plot(kind="line", ax=ax[0], title="Line")
df["Outcome"].value_counts().plot(kind="bar", ax=ax[1], title="Bar")
df["Outcome"].value_counts().plot(kind="pie", ax=ax[2], title="Pie")
plt.show()

# %% [markdown]
# **Perform Image Processing** in any random image file.
# a) Edge Detection
# b) Gray Scale

# %% [markdown]
# !wget -O sample.jpg https://upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Image_created_with_a_mobile_phone.png/640px-Image_created_with_a_mobile_phone.png
# img = cv2.imread('sample.jpg')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# edges = cv2.Canny(gray, 100, 200)
# plt.imshow(gray, cmap='gray'); plt.show()
# plt.imshow(edges, cmap='gray'); plt.show()

# %% [markdown]
# X_reg = df[['Glucose']].values
# y_reg = df['BMI'].values
# lr = LinearRegression().fit(X_reg, y_reg)
# y_p = lr.predict(X_reg)
# plt.scatter(X_reg, y_reg)
# plt.plot(X_reg, y_p, color='red')
# plt.show()
# print(f'MAE: {mean_absolute_error(y_reg, y_p)}')
# print(f'R2: {r2_score(y_reg, y_p)}')
